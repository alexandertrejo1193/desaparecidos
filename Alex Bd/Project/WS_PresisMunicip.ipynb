# %%
from bs4 import BeautifulSoup 
import requests 
import pandas as pd
url='http://www.snim.rami.gob.mx/info_historica.php?reporte=pmh&tipo=m'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
table = soup.find('div', attrs={'id': "datos"})
df1 = pd.read_html(str(table))[0]
df1
# Out:
#                       Presidente Municipal Sexo  \
# 0                           C. FELIPE RUIZ    H
# 1                        C. ZEFERINO MUÑOZ    H
# 2                          C. TOMÁS MEDINA    H
# 3                        C. EVARISTO FEMAT    H
# 4                    C. FRANCISCO ARMENGOL    H
# ..                                     ...  ...
# 69        C. JUAN ANTONIO MARTIN DEL CAMPO    H
# 70        C. MARIA TERESA JIMENEZ ESQUIVEL    M
# 71  ING. MARTHA MIRIAM RODRIGUEZ PISCAREÑO    M
# 72      LIC. MARIA TERESA JIMENEZ ESQUIVEL    M
# 73             C. LEONARDO MONTAÑEZ CASTRO    H
#
#                             Periodo         Partido
# 0                              1900             NaN
# 1                              1903             NaN
# 2                              1903             NaN
# 3                    de 1906 a 1913             NaN
# 4                    de 1907 a 1908             NaN
# ..                              ...             ...
# ...

# %%
url='http://www.snim.rami.gob.mx/combos.php'
response = requests.request('POST',url)
soup = BeautifulSoup(response.text, 'html.parser')
soup

# %%
table = soup.find('div', attrs={'id': "datos"})
    df1 = pd.read_html(str(table))[0]
    df1["Periodo"]=anio
    df1["Estado"]="AGUASCALIENTES"
    df=pd.concat([df, df1], sort=True,ignore_index=True)
