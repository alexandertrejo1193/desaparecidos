# %% [markdown]
# ## Circunstancias

# %%
import json
import pandas as pd
df={}
for i in range(16):
    ruta= '/Users/alexandertrejo/Documents/Locus Analytica/Desaparecidos/Alex/desaparecidos/Alex Bd/datos_procesados/circunstancias/'+str(i)+'.json'
    with open(ruta) as file:
        data = json.load(file)
        df_1 = pd.DataFrame(data)
        df[f'df{i+1}'] = df_1

# %%
df['df1']
# Out:
#                             totales  \
# PorcentajeDesaparecidos       40.61
# PorcentajeLocalizados         59.39
# PorcentajeLocalizadosCV       93.39
# PorcentajeLocalizadosSV        6.61
# PorcentajeSoloDesaparecidos   90.60
# PorcentajeSoloNoLocalizados    9.40
# TotalDesaparecidos            90195
# TotalGlobal                  222082
# TotalLocalizados             131887
# TotalLocalizadosCV           123164
# TotalLocalizadosSV             8723
# TotalSoloDesaparecidos        81714
# TotalSoloNoLocalizados         8481
# Hombre                          NaN
# Indeterminado                   NaN
# Mujer                           NaN
# Hombres                         NaN
# Mujeres                         NaN
#
#                                                                       espacial  \
# PorcentajeDesaparecidos                                                    NaN
# PorcentajeLocalizados                                                      NaN
# ...

# %%
df['df16']
# Out:
#                             totales  \
# PorcentajeDesaparecidos       69.32
# PorcentajeLocalizados         30.68
# PorcentajeLocalizadosCV       88.81
# PorcentajeLocalizadosSV       11.19
# PorcentajeSoloDesaparecidos   85.14
# PorcentajeSoloNoLocalizados   14.86
# TotalDesaparecidos              949
# TotalGlobal                    1369
# TotalLocalizados                420
# TotalLocalizadosCV              373
# TotalLocalizadosSV               47
# TotalSoloDesaparecidos          808
# TotalSoloNoLocalizados          141
# Hombre                          NaN
# Indeterminado                   NaN
# Mujer                           NaN
# Hombres                         NaN
# Mujeres                         NaN
#
#                                                                       espacial  \
# PorcentajeDesaparecidos                                                    NaN
# PorcentajeLocalizados                                                      NaN
# ...

# %% [markdown]
# ## Delitos

# %%
import json
import pandas as pd
df={}
for i in range(10):
    ruta= '/Users/alexandertrejo/Documents/Locus Analytica/Desaparecidos/Alex/desaparecidos/Alex Bd/datos_procesados/delitos/'+str(i)+'.json'
    with open(ruta) as file:
        data = json.load(file)
        df_1 = pd.DataFrame(data)
        df[f'df{i+1}'] = df_1

# %%
df['df1']
# Out:
#                             totales  \
# PorcentajeDesaparecidos       40.61
# PorcentajeLocalizados         59.39
# PorcentajeLocalizadosCV       93.39
# PorcentajeLocalizadosSV        6.61
# PorcentajeSoloDesaparecidos   90.60
# PorcentajeSoloNoLocalizados    9.40
# TotalDesaparecidos            90193
# TotalGlobal                  222080
# TotalLocalizados             131887
# TotalLocalizadosCV           123164
# TotalLocalizadosSV             8723
# TotalSoloDesaparecidos        81714
# TotalSoloNoLocalizados         8479
# Hombre                          NaN
# Indeterminado                   NaN
# Mujer                           NaN
# Hombres                         NaN
# Mujeres                         NaN
#
#                                                                       espacial  \
# PorcentajeDesaparecidos                                                    NaN
# PorcentajeLocalizados                                                      NaN
# ...

# %%
df['df10']
# Out:
#                             totales        espacial        anual  \
# PorcentajeDesaparecidos      100.00             NaN          NaN
# PorcentajeLocalizados          0.00             NaN          NaN
# PorcentajeLocalizadosCV        0.00             NaN          NaN
# PorcentajeLocalizadosSV        0.00             NaN          NaN
# PorcentajeSoloDesaparecidos  100.00             NaN          NaN
# PorcentajeSoloNoLocalizados    0.00             NaN          NaN
# TotalDesaparecidos               02             NaN          NaN
# TotalGlobal                      02             NaN          NaN
# TotalLocalizados                 00             NaN          NaN
# TotalLocalizadosCV               00             NaN          NaN
# TotalLocalizadosSV               00             NaN          NaN
# TotalSoloDesaparecidos           02             NaN          NaN
# TotalSoloNoLocalizados           00             NaN          NaN
# ...
