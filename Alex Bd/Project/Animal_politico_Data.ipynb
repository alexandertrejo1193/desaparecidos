# %%
import pandas as pd
actividades_tsv = "/Users/alexandertrejo/Documents/Locus Analytica/Desaparecidos/Alex/desaparecidos/Alex Bd/Project/pais-invadido/actividades.tsv"

df_actividades = pd.read_csv(actividades_tsv, delimiter="\t")

df_actividades
# Out:
#                        cartel presidente  estado
# 0                 guadalajara        JLP    1828
# 1                 guadalajara        JLP    1809
# 2                 guadalajara        JLP    1805
# 3                 guadalajara        JLP    1829
# 4                 guadalajara        JLP    1817
# ..                        ...        ...     ...
# 272  jalisco-nueva-generacion        EPN    1814
# 273  jalisco-nueva-generacion        EPN    1815
# 274  jalisco-nueva-generacion        EPN    1820
# 275  jalisco-nueva-generacion        EPN    1833
# 276  jalisco-nueva-generacion        EPN    1812
#
# [277 rows x 3 columns]

# %%
carteles_tsv = "/Users/alexandertrejo/Documents/Locus Analytica/Desaparecidos/Alex/desaparecidos/Alex Bd/Project/pais-invadido/carteles.tsv"

df_carteles = pd.read_csv(carteles_tsv, delimiter="\t")

df_carteles
# Out:
#                           id                    nombre  \
# 0                    milenio                   Milenio
# 1                    milenio                   Milenio
# 2                    milenio                   Milenio
# 3                    milenio                   Milenio
# 4                     oaxaca                    Oaxaca
# 5                     oaxaca                    Oaxaca
# 6                     oaxaca                    Oaxaca
# 7                     oaxaca                    Oaxaca
# 8                     oaxaca                    Oaxaca
# 9                     colima                    Colima
# 10                    colima                    Colima
# 11                    colima                    Colima
# 12             beltran-leyva             Beltrán Leyva
# 13             beltran-leyva             Beltrán Leyva
# 14  jalisco-nueva-generacion                       NaN
# 15  jalisco-nueva-generacion  Jalisco Nueva Generación
# ...

# %%
celulas_tsv = "/Users/alexandertrejo/Documents/Locus Analytica/Desaparecidos/Alex/desaparecidos/Alex Bd/Project/pais-invadido/celulas.tsv"

df_celulas = pd.read_csv(celulas_tsv, delimiter="\t")

df_celulas
# Out:
#     presidente              cartel                    nombre
# 0          EZP               golfo                 Los Zetas
# 1          VFQ             sinaloa                      FEDA
# 2          VFQ             sinaloa               Los Pelones
# 3          VFQ              juarez                  La Línea
# 4          VFQ               golfo                 Los Zetas
# ..         ...                 ...                       ...
# 102        EPN               zetas          Grupo Delta Zeta
# 103        EPN               zetas                Los Negros
# 104        EPN               zetas  Fuerzas Especiales Zetas
# 105        EPN  familia-michoacana          Guerreros Unidos
# 106        EPN  familia-michoacana                La Empresa
#
# [107 rows x 3 columns]

# %%
conflictos_tsv = "/Users/alexandertrejo/Documents/Locus Analytica/Desaparecidos/Alex/desaparecidos/Alex Bd/Project/pais-invadido/conflictos.tsv"

df_conflictos = pd.read_csv(conflictos_tsv, delimiter="\t")

df_conflictos
# Out:
#    presidente                      bando1                  bando2  \
# 0         CSG                     tijuana                  juarez
# 1         CSG                     tijuana                 sinaloa
# 2         CSG                     tijuana  milenio|sinaloa|juarez
# 3         EZP                     tijuana  milenio|sinaloa|juarez
# 4         VFQ                     tijuana  milenio|sinaloa|juarez
# 5         VFQ                       golfo  milenio|sinaloa|juarez
# 6         VFQ                       golfo                 milenio
# 7         VFQ               tijuana|golfo                 sinaloa
# 8         VFQ                     sinaloa                  juarez
# 9         VFQ                     tijuana                 sinaloa
# 10        VFQ                     tijuana                  juarez
# 11        VFQ                       golfo                  juarez
# 12        VFQ                       golfo                 sinaloa
# ...

# %%
estados_tsv = "/Users/alexandertrejo/Documents/Locus Analytica/Desaparecidos/Alex/desaparecidos/Alex Bd/Project/pais-invadido/estados.tsv"

df_estados = pd.read_csv(estados_tsv, delimiter="\t")

df_estados
# Out:
#       id               estado abreviacion
# 0   1804       Aguascalientes         AGS
# 1   1805      Baja California          BC
# 2   1806  Baja California Sur         BCS
# 3   1807             Campeche        CAMP
# 4   1808              Chiapas        CHIS
# 5   1809            Chihuahua        CHIH
# 6   1810             Coahuila        COAH
# 7   1811               Colima         COL
# 8   1812     Distrito Federal          DF
# 9   1813              Durango         DGO
# 10  1814           Guanajuato         GTO
# 11  1815             Guerrero         GRO
# 12  1816              Hidalgo         HGO
# 13  1817              Jalisco         JAL
# 14  1818     Estado de México         MEX
# 15  1819            Michoacán        MICH
# 16  1820              Morelos         MOR
# 17  1821              Nayarit         NAY
# 18  1822           Nuevo León          NL
# 19  1823               Oaxaca         OAX
# 20  1824               Puebla         PUE
# ...

# %%
eventos_tsv = "/Users/alexandertrejo/Documents/Locus Analytica/Desaparecidos/Alex/desaparecidos/Alex Bd/Project/pais-invadido/eventos.tsv"

df_eventos = pd.read_csv(eventos_tsv, delimiter="\t")

df_eventos
# Out:
#      anio                                        descripcion  \
# 0    1975  Operación Cóndor. Despliegue del Ejército mexi...
# 1    1984  Operación Rancho Búfalo. Fuerzas federales des...
# 2    1985  Asesinato del agente de la DEA Enrique Camaren...
# 3    1985  Desaparece la Dirección Federal de Seguridad (...
# 4    1988  Se crea la Subprocuraduría de Investigación y ...
# ..    ...                                                ...
# 172  2014  Es abatido en Queretaro, durante un enfrentami...
# 173  2014  Detención de José Juan Esparragoza Jiménez, 'E...
# 174  2014  Detención de Héctor Beltrán Leyva, líder del c...
# 175  2014  Detención de Vicente Carrillo Fuentes, 'El Vic...
# 176  2014  Detención de Ismael Zambada Imperial, hijo de ...
#
#                                                titular  \
# 0                                     Operación Cóndor
# 1                              Operación Rancho Búfalo
# 2                        Asesinato de Enrique Camarena
# ...

# %%
federaciones_tsv = "/Users/alexandertrejo/Documents/Locus Analytica/Desaparecidos/Alex/desaparecidos/Alex Bd/Project/pais-invadido/federaciones.tsv"

df_federaciones = pd.read_csv(federaciones_tsv, delimiter="\t")

df_federaciones
# Out:
#              id        nombre  \
# 0  federacion-1  Federación 1
# 1  federacion-2  Federación 2
#
#                                            lideres  inicio   fin    color  \
# 0  Amado Carrillo Fuentes 'El señor de Los Cielos'    1993  1998  #e9f4dc
# 1                        Joaquín 'El Chapo' Guzmán    2001  2004  #f9edd6
#
#     fuente
# 0  #8fc64f
# 1  #e1a632

# %%
federacionescarteles_tsv = "/Users/alexandertrejo/Documents/Locus Analytica/Desaparecidos/Alex/desaparecidos/Alex Bd/Project/pais-invadido/federacionescarteles.tsv"

df_federacionescarteles = pd.read_csv(federacionescarteles_tsv, delimiter="\t")

df_federacionescarteles
# Out:
#              id                 aliados   involucrados
# 0  federacion-1  milenio|sinaloa|juarez        tijuana
# 1  federacion-2  milenio|sinaloa|juarez  tijuana|golfo

# %%
presidentes_tsv = "/Users/alexandertrejo/Documents/Locus Analytica/Desaparecidos/Alex/desaparecidos/Alex Bd/Project/pais-invadido/presidentes.tsv"

presidentes_origenes = pd.read_csv(presidentes_tsv, delimiter="\t")

presidentes_origenes
# Out:
#     id               nombre  inicio             fotografia     nombrecorto
# 0  JLP  José López Portillo    1976  01_Lopez_Portillo.png  López Portillo
# 1  MMH  Miguel de la Madrid    1982    02_De_la_Madrid.png    De la Madrid
# 2  CSG       Carlos Salinas    1988         03_Salinas.png         Salinas
# 3  EZP      Ernesto Zedillo    1994         04_Zedillo.png         Zedillo
# 4  VFQ          Vicente Fox    2000             05_Fox.png             Fox
# 5  FCH      Felipe Calderón    2006        06_Calderon.png        Calderón
# 6  EPN   Enrique Peña Nieto    2012             07_EPN.png      Peña Nieto

# %%
origenes_tsv = "/Users/alexandertrejo/Documents/Locus Analytica/Desaparecidos/Alex/desaparecidos/Alex Bd/Project/pais-invadido/origenes.tsv"

df_origenes = pd.read_csv(origenes_tsv, delimiter="\t")

df_origenes
# Out:
#                origen                   destino  offset
# 0             sinaloa             beltran-leyva       0
# 1             sinaloa  jalisco-nueva-generacion       0
# 2               golfo                     zetas      15
# 3               zetas        familia-michoacana       0
# 4  familia-michoacana     caballeros-templarios       0

# %%
resumencarteles_tsv = "/Users/alexandertrejo/Documents/Locus Analytica/Desaparecidos/Alex/desaparecidos/Alex Bd/Project/pais-invadido/federacionescarteles.tsv"

df_resumencarteles = pd.read_csv(resumencarteles_tsv, delimiter="\t")

df_resumencarteles
# Out:
#              id                 aliados   involucrados
# 0  federacion-1  milenio|sinaloa|juarez        tijuana
# 1  federacion-2  milenio|sinaloa|juarez  tijuana|golfo

# %%
df_actividades= df_actividades.rename(columns={'estado': 'estado_id'})
df_actividades= df_actividades.rename(columns={'presidente': 'presidente_id'})
presidentes_origenes=presidentes_origenes.rename(columns={'id': 'presidente_id'})
df_estados= df_estados.rename(columns={'id': 'estado_id'})
tablaconjunta=pd.merge(df_actividades,df_estados,on="estado_id",how="inner")
tablaconjunta=pd.merge(tablaconjunta,presidentes_origenes,on="presidente_id",how="inner")
tablaconjunta=tablaconjunta[['inicio','estado','cartel','nombre']]

# %%
tablaconjunta= tablaconjunta.rename(columns={'inicio': 'año'})
tablaconjunta= tablaconjunta.rename(columns={'nombre': 'presidente'})
tablaconjunta
# Out:
#       año            estado                    cartel           presidente
# 0    1976           Sinaloa               guadalajara  José López Portillo
# 1    1976         Chihuahua               guadalajara  José López Portillo
# 2    1976   Baja California               guadalajara  José López Portillo
# 3    1976            Sonora               guadalajara  José López Portillo
# 4    1976           Jalisco               guadalajara  José López Portillo
# ..    ...               ...                       ...                  ...
# 272  2012           Morelos  jalisco-nueva-generacion   Enrique Peña Nieto
# 273  2012    Aguascalientes             beltran-leyva   Enrique Peña Nieto
# 274  2012  Estado de México        familia-michoacana   Enrique Peña Nieto
# 275  2012  Estado de México     caballeros-templarios   Enrique Peña Nieto
# 276  2012         Querétaro     caballeros-templarios   Enrique Peña Nieto
#
# [277 rows x 4 columns]

# %%
tablaconjunta.to_excel('Cartel_anio_estado_presi.xlsx', index=False)
